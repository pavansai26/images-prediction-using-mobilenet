# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import seaborn as sns
import math
import os

# %%
from keras.models import model_from_json
from keras.preprocessing import image
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.utils import np_utils
import keras
import keras.backend as K
from keras.models import Model
from keras.layers import Input, Dense, Conv2D
from keras.layers import Flatten, MaxPool2D
from keras.layers import  Dropout, ReLU
from keras.layers import DepthwiseConv2D

#from IPython.display import SVG
#from keras.utils.vis_utils import model_to_dot

from time import time
import numpy as np
import cv2
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
def trainingdata():
    training_data = []
    file='C:/Users/lenovo/Downloads/challenges-in-representation-learning-facial-expression-recognition-challenge/daaata'
    categories=['pavan','balaji','krishna','shakeel','abhilash']
    for category in categories:
        path = os.path.join(file,category)
        class_num = categories.index(category)
        for img in (os.listdir(path)):
            try:
                img_array = cv2.imread(os.path.join(path,img) ,cv2.IMREAD_GRAYSCALE)
                new_array = cv2.resize(img_array, (50,50))
                training_data.append([new_array, class_num])
            except Exception as e:
                pass
    return training_data

# %%
from tensorflow.keras.preprocessing.image import *
import tensorflow as tf

# %%
train_datagen = ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True,\
 width_shift_range=0.2,
 height_shift_range=0.2,
 channel_shift_range=0.1,
 vertical_flip=True,
 rotation_range=30)

# %%
file='C:/Users/lenovo/Downloads/challenges-in-representation-learning-facial-expression-recognition-challenge/daaata/pavan.jpg'

# %%
i=0
for img in os.listdir(file):
        for batch in  train_datagen.flow(img,batch_size=1,save_to_dir='C:/Users/lenovo/Downloads/challenges-in-representation-learning-facial-expression-recognition-challenge/pavan',
save_prefix='pavan',save_format='jpg'):
            i+=1
            if i>100:
                break
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-11-0bedb305c984> in <module>
#       1 i=0
# ----> 2 for img in os.listdir(file):
#       3         for batch in  train_datagen.flow(img,batch_size=1,save_to_dir='C:/Users/lenovo/Downloads/challenges-in-representation-learning-facial-expression-recognition-challenge/pavan',
#       4 save_prefix='pavan',save_format='jpg'):
#       5             i+=1
#
# NotADirectoryError: [WinError 267] The directory name is invalid: 'C:/Users/lenovo/Downloads/challenges-in-representation-learning-facial-expression-recognition-challenge/daaata/pavan.jpg'

# %%
train_datagen = ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True,\
 width_shift_range=0.2,
 height_shift_range=0.2,
 channel_shift_range=0.1,
 vertical_flip=True,
 rotation_range=30)
img=load_img('C:/Users/lenovo/Downloads/challenges-in-representation-learning-facial-expression-recognition-challenge/daaata/pavan.jpg')
x=img_to_array(img)
x=x.reshape((1,)+x.shape)
i=0
for batch in train_datagen.flow(x,batch_size=1,save_to_dir='C:/Users/lenovo/Downloads/challenges-in-representation-learning-facial-expression-recognition-challenge/daaata/pavan',
save_prefix='pavan',save_format='jpg'):
    i+=1
    if i>100:
        break
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-2daea328bb01> in <module>
#      10 i=0
#      11 for batch in train_datagen.flow(x,batch_size=1,save_to_dir='C:/Users/lenovo/Downloads/challenges-in-representation-learning-facial-expression-recognition-challenge/pavan',
# ---> 12 save_prefix='pavan',save_format='jpg'):
#      13     i+=1
#      14     if i>100:
#
# ~\Anaconda3\lib\site-packages\keras_preprocessing\image\iterator.py in __next__(self, *args, **kwargs)
#     102
#     103     def __next__(self, *args, **kwargs):
# --> 104         return self.next(*args, **kwargs)
#     105
#     106     def next(self):
#
# ~\Anaconda3\lib\site-packages\keras_preprocessing\image\iterator.py in next(self)
#     114         # The transformation of images is not under thread lock
#     115         # so it can be done in parallel
# ...

# %%
img=load_img('C:/Users/lenovo/Downloads/challenges-in-representation-learning-facial-expression-recognition-challenge/daaata/pavan.jpg')
y=img_to_array(img)
x=y.reshape((1,)+y.shape)
print(x.shape)
plt.imshow(x[1:])
# Out:
# (1, 4608, 2128, 3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-f4e5da93b831> in <module>
#       3 x=y.reshape((1,)+y.shape)
#       4 print(x.shape)
# ----> 5 plt.imshow(x[1:])
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2697         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2698         resample=resample, url=url, **({"data": data} if data is not
# -> 2699         None else {}), **kwargs)
#    2700     sci(__ret)
#    2701     return __ret
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...

# %%
import cv2

# %%
img=load_img('C:/Users/lenovo/Downloads/challenges-in-representation-learning-facial-expression-recognition-challenge/daaata/abhilash.jpg')

# %%
y=img_to_array(img)
new=cv2.resize(y,(50,50))
x=new.reshape((1,)+new.shape)

# %%
i=0
for batch in train_datagen.flow(x,batch_size=1,save_to_dir='C:/Users/lenovo/Downloads/challenges-in-representation-learning-facial-expression-recognition-challenge/daaata/abhilash',
save_prefix='abhilash',save_format='jpg'):
    i+=1
    if i>100:
        break

# %%
def trainingdata():
    training_data = []
    file='C:/Users/lenovo/Downloads/challenges-in-representation-learning-facial-expression-recognition-challenge/daaata'
    categories=['pavan','balaji','krishna','shakeel','abhilash']
    for category in categories:
        path = os.path.join(file,category)
        class_num = categories.index(category)
        for img in (os.listdir(path)):
            try:
                img_array = cv2.imread(os.path.join(path,img) ,cv2.IMREAD_GRAYSCALE)
                new_array = cv2.resize(img_array, (50,50))
                training_data.append([new_array, class_num])
            except Exception as e:
                pass
    return training_data

# %%
trainingdata()
# Out:
# [[array([[232, 232, 232, ..., 231, 229, 229],
#          [232, 232, 232, ..., 231, 230, 230],
#          [232, 232, 232, ..., 231, 231, 231],
#          ...,
#          [158, 157, 156, ..., 151, 153, 152],
#          [152, 151, 150, ..., 149, 153, 158],
#          [124, 122, 121, ..., 140, 118, 124]], dtype=uint8), 0],
#  [array([[230, 230, 230, ..., 231, 231, 231],
#          [230, 230, 230, ..., 231, 231, 231],
#          [230, 230, 230, ..., 231, 231, 231],
#          ...,
#          [240, 243, 247, ...,  68,  67,  76],
#          [252, 246, 247, ...,  78,  69,  70],
#          [249, 242, 243, ...,  78,  69,  70]], dtype=uint8), 0],
#  [array([[234, 234, 233, ..., 230, 230, 230],
#          [234, 234, 234, ..., 230, 231, 231],
#          [235, 235, 234, ..., 230, 231, 231],
#          ...,
#          [ 90,  65,  81, ..., 235, 230, 230],
#          [ 80,  72,  81, ..., 238, 220, 233],
#          [ 80,  72,  81, ..., 187, 205, 218]], dtype=uint8), 0],
# ...

# %% [markdown]
# def modelbuilding():
#     import random
#     from keras.initializers import glorot_uniform
#     from keras.utils import CustomObjectScope
#     random.shuffle(trainingdata())
#     X1 = []
#     y1 = []
#     for features,label in trainingdata():
#         X1.append(features)
#         y1.append(label)
#     x2=np.array(X1).reshape(-1,50,50,1)
#     y2=np.array(y1)
#     ip=np.array(x2)
#     model1=tf.keras.models.Sequential([ tf.keras.layers.Conv2D(64,(3,3),activation='relu',
#                                                                input_shape=(ip.shape[1:])),
#                                        tf.keras.layers.BatchNormalization(), tf.keras.layers.ReLU(),
#                                        tf.keras.layers.DepthwiseConv2D(3,strides=1,padding='same'),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.Conv2D(64,(1,1)),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.DepthwiseConv2D(3,strides=2,padding='same'),
#                                        tf.keras.layers.BatchNormalization(), tf.keras.layers.ReLU(),
#                                        tf.keras.layers.Conv2D(128,(1,1)),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.DepthwiseConv2D(3,strides=1,padding='same'),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.Conv2D(128,(1,1)),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.DepthwiseConv2D(3,strides=2,padding='same'),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.Conv2D(256,(1,1)),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.DepthwiseConv2D(3,strides=1,padding='same'),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.Conv2D(256,(1,1)),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.Dropout(0.2)
#                                        tf.keras.layers.DepthwiseConv2D(3,strides=2,padding='same'),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.Conv2D(512,(1,1)),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU()
#                                        tf.keras.layers.DepthwiseConv2D(3,strides=1,padding='same'),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.Conv2D(512,(1,1)),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.DepthwiseConv2D(3,strides=2,padding='same'),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.Conv2D(512,(1,1)),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.DepthwiseConv2D(3,strides=1,padding='same'),
#                                        tf.keras.layers.BatchNormalization(), tf.keras.layers.ReLU(),
#                                        tf.keras.layers.Conv2D(512,(1,1)),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.DepthwiseConv2D(3,strides=2,padding='same'),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.Conv2D(512,(1,1)),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.DepthwiseConv2D(3,strides=1,padding='same'),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.Conv2D(512,(1,1)),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.Dropout(0.2)
#                                        tf.keras.layers.DepthwiseConv2D(3,strides=2,padding='same'),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.Conv2D(1024,(1,1)),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.DepthwiseConv2D(3,strides=1,padding='same'),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.Conv2D(512,(1,1)),
#                                        tf.keras.layers.BatchNormalization(),
#                                        tf.keras.layers.ReLU(),
#                                        tf.keras.layers.Dropout(0.2)
#                                        tf.keras.layers.GlobalAvgPool2D()
#                                        tf.keras.layers.Dense(6,activation='softmax')]
#     model1.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
#     target=np.array(y2)
#     model1.fit(ip,target,epochs=1)
#     #from keras.models import load_model
#     model1.save('my_model1.h5')  # creates a HDF5 file 'my_model.h5'
#     #modelfac=tf.keras.models.load_model('my_model1.h5')
#     #return modelfac

# %%
import random
from keras.initializers import glorot_uniform
from keras.utils import CustomObjectScope
random.shuffle(trainingdata())
X1 = []
y1 = []
for features,label in trainingdata():
    X1.append(features)
    y1.append(label)
x2=np.array(X1).reshape(-1,50,50,1)
y2=np.array(y1)
ip=np.array(x2)
model1=tf.keras.models.Sequential([ tf.keras.layers.Conv2D(64,(3,3),activation='relu',
                                                           input_shape=(ip.shape[1:])),
                                   tf.keras.layers.BatchNormalization(), tf.keras.layers.ReLU(),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=1,padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(64,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Dropout(0.2),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=2,padding='same'),
                                   tf.keras.layers.BatchNormalization(), tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(128,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=1,padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(128,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=2,padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(256,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Dropout(0.2),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=1,padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(256,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Dropout(0.2),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=2,padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(512,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=1,padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(512,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=(2,2),padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(512,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Dropout(0.2),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=(1,1),padding='same'),
                                   tf.keras.layers.BatchNormalization(), tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(512,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=(2,2),padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(512,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=(1,1),padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(512,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=(2,2),padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(1024,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Dropout(0.2),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=(1,1),padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(512,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(), 
                                   tf.keras.layers.GlobalAvgPool2D(), 
                                   tf.keras.layers.Dense(6,activation='softmax')])
model1.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
target=np.array(y2)
model1.fit(ip,target,epochs=20)
# Out:
# Train on 504 samples
# Epoch 1/20
# 504/504 [==============================] - 89s 176ms/sample - loss: 1.6059 - accuracy: 0.3433
# Epoch 2/20
# 504/504 [==============================] - 40s 78ms/sample - loss: 1.3010 - accuracy: 0.4980
# Epoch 3/20
# 504/504 [==============================] - 39s 77ms/sample - loss: 1.2270 - accuracy: 0.4802
# Epoch 4/20
# 504/504 [==============================] - 38s 76ms/sample - loss: 1.0842 - accuracy: 0.5714
# Epoch 5/20
# 504/504 [==============================] - 42s 83ms/sample - loss: 0.9322 - accuracy: 0.6012
# Epoch 6/20
# 504/504 [==============================] - 41s 82ms/sample - loss: 0.8679 - accuracy: 0.6687
# Epoch 7/20
# 504/504 [==============================] - 39s 78ms/sample - loss: 0.6567 - accuracy: 0.7222
# Epoch 8/20
# 504/504 [==============================] - 39s 77ms/sample - loss: 0.6818 - accuracy: 0.7222
# Epoch 9/20
# 504/504 [==============================] - 38s 76ms/sample - loss: 0.6903 - accuracy: 0.7540
# ...

# %%
import tkinter as tk
from tkinter import filedialog
filename = filedialog.askopenfilename()
im_arr=cv2.imread(filename)
img_array = cv2.imread(filename ,cv2.IMREAD_GRAYSCALE)  
new_array = cv2.resize(img_array, (50,50))
xtest=new_array/255.0
g=np.array(xtest).reshape(1,50,50,1)
prob=model1.predict(g)
number_to_class=['pavan','balaji','krishna','shakeel','abhilash']
sorti=np.argmax(prob)
print('most likely class:',number_to_class[sorti])
# Out:
# most likely class: shakeel

# %%
pip install face_recognition
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/63/92/05c3b98636661cb80d190a5a777dd94effcc14c0f6893222e5ca81e74fbc/dlib-19.19.0.tar.gz
# ...
#   Complete output from command C:\Users\lenovo\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\lenovo\\AppData\\Local\\Temp\\pip-install-9sxkeqpl\\dlib\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d C:\Users\lenovo\AppData\Local\Temp\pip-wheel-agiellwl --python-tag cp37:
#   running bdist_wheel
#   running build
#   running build_py
#   package init file 'dlib\__init__.py' not found (or not a regular file)
#   running build_ext
#   Building extension for Python 3.7.3 (default, Mar 27 2019, 17:13:21) [MSC v.1915 64 bit (AMD64)]
# ...
